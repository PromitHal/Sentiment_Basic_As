# %% [markdown]
# ### Download and import packages

# %%
'''
Installing dependencies...
'''
# uninstall
# !pip uninstall -y wandb
# download
# !pip install transformers
# !pip install google-play-scraper
#----------------------------------------------------------------------------------------------------------------------------------------------------------------
'''
Importing modules
'''
import re
import json
import torch
import random
import pandas as pd
from tqdm import tqdm
from torch.utils.data import Dataset
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split
from google_play_scraper import app,Sort,reviews_all
import pandas as pd
import numpy as np
from google_play_scraper import Sort, reviews
# Out:
# WARNING: Skipping wandb as it is not installed.
# Requirement already satisfied: transformers in /opt/conda/lib/python3.7/site-packages (4.5.1)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /opt/conda/lib/python3.7/site-packages (from transformers) (0.10.2)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.7/site-packages (from transformers) (1.19.5)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.7/site-packages (from transformers) (4.59.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.7/site-packages (from transformers) (20.9)
# Requirement already satisfied: sacremoses in /opt/conda/lib/python3.7/site-packages (from transformers) (0.0.45)
# Requirement already satisfied: requests in /opt/conda/lib/python3.7/site-packages (from transformers) (2.25.1)
# Requirement already satisfied: importlib-metadata in /opt/conda/lib/python3.7/site-packages (from transformers) (3.4.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.7/site-packages (from transformers) (3.0.12)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.7/site-packages (from transformers) (2021.3.17)
# Requirement already satisfied: typing-extensions>=3.6.4 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata->transformers) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata->transformers) (3.4.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/lib/python3.7/site-packages (from packaging->transformers) (2.4.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests->transformers) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests->transformers) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests->transformers) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests->transformers) (2.10)
# Requirement already satisfied: click in /opt/conda/lib/python3.7/site-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.7/site-packages (from sacremoses->transformers) (1.0.1)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: google-play-scraper in /opt/conda/lib/python3.7/site-packages (1.2.4)

# %%
result, continuation_token = reviews(
    'cris.org.in.prs.ima', 
    lang='en', 
    country='us',
    count=10000,
    sort=Sort.NEWEST, 
)
#Assembling reviews into a pandas dataframe for better pipelining
df_review=pd.DataFrame(np.array(result),columns=['review'])
df_review=df_review.join(pd.DataFrame(df_review.pop('review').tolist()))
features=df_review['content']
targets=df_review['score']
features=list(features)
targets=list(targets)
new_targets=[]
num_pos=0
num_neg=0
for rows in range(len(targets)):
    temp_score=targets[rows]
    if temp_score>=3:
        new_targets.append(1)
        num_pos+=1
    else:
        new_targets.append(0)
        num_neg+=1
features=list(features)
targets=list(new_targets)

# %% [markdown]
# ### Dataset load and prep functions

# %%
# Dataset class
class SentimentDataset(Dataset):
    def __init__(self, txt_list, label_list, tokenizer, max_length):
        # define variables    
        self.input_ids = []
        self.attn_masks = []
        self.labels = []
        map_label = {0:'negative', 1: 'positive'}
        # iterate through the dataset
        for txt, label in zip(txt_list, label_list):
            # prepare the text
            prep_txt = f'<|startoftext|>Review: {txt}\nSentiment: {map_label[label]}<|endoftext|>'
            # tokenize
            encodings_dict = tokenizer(prep_txt, truncation=True,
                                       max_length=max_length, padding="max_length")
            # append to list
            self.input_ids.append(torch.tensor(encodings_dict['input_ids']))
            self.attn_masks.append(torch.tensor(encodings_dict['attention_mask']))
            self.labels.append(map_label[label])

    def __len__(self):
        return len(self.input_ids)

    def __getitem__(self, idx):
        return self.input_ids[idx], self.attn_masks[idx], self.labels[idx]

# Data load function
def load_sentiment_dataset(tokenizer, random_seed = 42, file_path="../input/sentiment140/training.1600000.processed.noemoticon.csv"):
    
    df=pd.DataFrame({
        "text":features,
        "label":targets
        
    })
    def pick_first_n_words(string, max_words=250): # tried a few max_words, kept 250 as max tokens was < 512
        split_str = string.split()
        return " ".join(split_str[:min(len(split_str), max_words)])

    df['text'] = df['text'].apply(lambda x: pick_first_n_words(x))
    
    # divide into test and train
    X_train, X_test, y_train, y_test = \
              train_test_split(df['text'].tolist(), df['label'].tolist(),
              shuffle=True, test_size=0.05, random_state=random_seed, stratify=df['label'])

    # get max length
    max_length_train = max([len(tokenizer.encode(text)) for text in X_train])
    max_length_test = max([len(tokenizer.encode(text)) for text in X_test])
    max_length = max([max_length_train, max_length_test]) + 10  #for special tokens (sos and eos) and fillers
    max_length = max(max_length, 300)
    print(f"Setting max length as {max_length}")

    # format into SentimentDataset class
    train_dataset = SentimentDataset(X_train, y_train, tokenizer, max_length=max_length)

    # return
    return train_dataset, (X_test, y_test)

# %% [markdown]
# ### Load model and tokenizer; Call data Prep

# %%
# import 
from torch.utils.data import Dataset, random_split
from transformers import GPT2Tokenizer, TrainingArguments, Trainer, GPT2LMHeadModel

# model
model_name = "gpt2"
seed = 42

# seed
torch.manual_seed(seed)

# %%
features=features[:5000]
targets=targets[:5000]

# %%
model = GPT2LMHeadModel.from_pretrained(model_name).cuda()
model.resize_token_embeddings(len(tokenizer))

epochs=1
print("Loading model...")

# load tokenizer and model
tokenizer = GPT2Tokenizer.from_pretrained(model_name, bos_token='<|startoftext|>',
                                          eos_token='<|endoftext|>', pad_token='<|pad|>')

for trial_no in range(epochs):
 
    model=model.train()
    print("Loading dataset...")
    train_dataset, test_dataset = load_sentiment_dataset(tokenizer)

    print("Epoch: {}".format(trial_no))
    training_args = TrainingArguments(output_dir='results', num_train_epochs=2, 
                                    logging_steps=10, load_best_model_at_end=True,
                                      save_strategy="epoch", per_device_train_batch_size=2, per_device_eval_batch_size=2,
                                    warmup_steps=100, weight_decay=0.01, logging_dir='logs')

    Trainer(model=model, args=training_args, train_dataset=train_dataset,
            eval_dataset=test_dataset, data_collator=lambda data: {'input_ids': torch.stack([f[0] for f in data]),
                                                                  'attention_mask': torch.stack([f[1] for f in data]),
                                                                  'labels': torch.stack([f[0] for f in data])}).train()
    
    # test
    print("Start testing...")
    # eval mode on model
    model = model.eval()

    # compute prediction on test data
    original, predicted, all_text, predicted_text = [], [], [], []
    map_label = {0:'negative', 1: 'positive'}
    with torch.no_grad():
        for text, label in tqdm(zip(test_dataset[0], test_dataset[1])):
            # predict sentiment on test data
            prompt = f'<|startoftext|>Review: {text}\nSentiment:'
            generated = tokenizer(f"<|startoftext|> {prompt}", return_tensors="pt").input_ids.cuda()
            sample_outputs = model.generate(generated, do_sample=False, top_k=50, max_length=512, top_p=0.90, 
                    temperature=0, num_return_sequences=0)
            pred_text = tokenizer.decode(sample_outputs[0], skip_special_tokens=True)
            # extract the predicted sentiment
            try:
                pred_sentiment = re.findall("\nSentiment: (.*)", pred_text)[-1]
            except:
                pred_sentiment = "None"
            original.append(map_label[label])
            predicted.append(pred_sentiment)
            all_text.append(text)
            predicted_text.append(pred_text)
    #transform into dataframe
    df = pd.DataFrame({'text': all_text, 'predicted': predicted, 'original': original, 'predicted_text': predicted_text})
    df.to_csv(f"result_run_{trial_no}.csv", index=False)
    # compute f1 score
    print(f1_score(original, predicted, average='macro'))
# Out:
# Loading model...
# Special tokens have been added in the vocabulary, make sure the associated word embedding are fine-tuned or trained.
# Loading dataset...
# Setting max length as 961
# Epoch: 0
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#         </style>
#
#       <progress value='4750' max='4750' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [4750/4750 52:18, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>8.573900</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>7.406500</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>4.167300</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>1.316000</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.484400</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.186600</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.132000</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.068900</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.158700</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.095400</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.161400</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.192700</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>0.146700</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>0.098600</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.071000</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>0.153700</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>0.080100</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>0.079300</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>0.094800</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.117400</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>0.127500</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>0.065300</td>
#     </tr>
#     <tr>
#       <td>230</td>
#       <td>0.115000</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>0.082700</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.092200</td>
#     </tr>
#     <tr>
#       <td>260</td>
#       <td>0.066300</td>
#     </tr>
#     <tr>
#       <td>270</td>
#       <td>0.086400</td>
#     </tr>
#     <tr>
#       <td>280</td>
#       <td>0.071900</td>
#     </tr>
#     <tr>
#       <td>290</td>
#       <td>0.101300</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.089300</td>
#     </tr>
#     <tr>
#       <td>310</td>
#       <td>0.103900</td>
#     </tr>
#     <tr>
#       <td>320</td>
#       <td>0.114300</td>
#     </tr>
#     <tr>
#       <td>330</td>
#       <td>0.095300</td>
#     </tr>
#     <tr>
#       <td>340</td>
#       <td>0.072500</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.093800</td>
#     </tr>
#     <tr>
#       <td>360</td>
#       <td>0.161200</td>
#     </tr>
#     <tr>
#       <td>370</td>
#       <td>0.066700</td>
#     </tr>
#     <tr>
#       <td>380</td>
#       <td>0.098200</td>
#     </tr>
#     <tr>
#       <td>390</td>
#       <td>0.074300</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.100600</td>
#     </tr>
#     <tr>
#       <td>410</td>
#       <td>0.097100</td>
#     </tr>
#     <tr>
#       <td>420</td>
#       <td>0.100200</td>
#     </tr>
#     <tr>
#       <td>430</td>
#       <td>0.089200</td>
#     </tr>
#     <tr>
#       <td>440</td>
#       <td>0.115400</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.073900</td>
#     </tr>
#     <tr>
#       <td>460</td>
#       <td>0.040700</td>
#     </tr>
#     <tr>
#       <td>470</td>
#       <td>0.113300</td>
#     </tr>
#     <tr>
#       <td>480</td>
#       <td>0.109100</td>
#     </tr>
#     <tr>
#       <td>490</td>
#       <td>0.093500</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.130500</td>
#     </tr>
#     <tr>
#       <td>510</td>
#       <td>0.067100</td>
#     </tr>
#     <tr>
#       <td>520</td>
#       <td>0.115500</td>
#     </tr>
#     <tr>
#       <td>530</td>
#       <td>0.093900</td>
#     </tr>
#     <tr>
#       <td>540</td>
#       <td>0.113700</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>0.075000</td>
#     </tr>
#     <tr>
#       <td>560</td>
#       <td>0.086000</td>
#     </tr>
#     <tr>
#       <td>570</td>
#       <td>0.074100</td>
#     </tr>
#     <tr>
#       <td>580</td>
#       <td>0.083400</td>
#     </tr>
#     <tr>
#       <td>590</td>
#       <td>0.104700</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.066200</td>
#     </tr>
#     <tr>
#       <td>610</td>
#       <td>0.074300</td>
#     </tr>
#     <tr>
#       <td>620</td>
#       <td>0.116500</td>
#     </tr>
#     <tr>
#       <td>630</td>
#       <td>0.160600</td>
#     </tr>
#     <tr>
#       <td>640</td>
#       <td>0.057300</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>0.061100</td>
#     </tr>
#     <tr>
#       <td>660</td>
#       <td>0.086600</td>
#     </tr>
#     <tr>
#       <td>670</td>
#       <td>0.131500</td>
#     </tr>
#     <tr>
#       <td>680</td>
#       <td>0.050800</td>
#     </tr>
#     <tr>
#       <td>690</td>
#       <td>0.045100</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.076500</td>
#     </tr>
#     <tr>
#       <td>710</td>
#       <td>0.066700</td>
#     </tr>
#     <tr>
#       <td>720</td>
#       <td>0.112100</td>
#     </tr>
#     <tr>
#       <td>730</td>
#       <td>0.047400</td>
#     </tr>
#     <tr>
#       <td>740</td>
#       <td>0.076100</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>0.051600</td>
#     </tr>
#     <tr>
#       <td>760</td>
#       <td>0.060200</td>
#     </tr>
#     <tr>
#       <td>770</td>
#       <td>0.093600</td>
#     </tr>
#     <tr>
#       <td>780</td>
#       <td>0.113300</td>
#     </tr>
#     <tr>
#       <td>790</td>
#       <td>0.100700</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.155300</td>
#     </tr>
#     <tr>
#       <td>810</td>
#       <td>0.102800</td>
#     </tr>
#     <tr>
#       <td>820</td>
#       <td>0.060700</td>
#     </tr>
#     <tr>
#       <td>830</td>
#       <td>0.092900</td>
#     </tr>
#     <tr>
#       <td>840</td>
#       <td>0.062100</td>
#     </tr>
#     <tr>
#       <td>850</td>
#       <td>0.192500</td>
#     </tr>
#     <tr>
#       <td>860</td>
#       <td>0.084000</td>
#     </tr>
#     <tr>
#       <td>870</td>
#       <td>0.116000</td>
#     </tr>
#     <tr>
#       <td>880</td>
#       <td>0.093100</td>
#     </tr>
#     <tr>
#       <td>890</td>
#       <td>0.158300</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.126000</td>
#     </tr>
#     <tr>
#       <td>910</td>
#       <td>0.151000</td>
#     </tr>
#     <tr>
#       <td>920</td>
#       <td>0.089600</td>
#     </tr>
#     <tr>
#       <td>930</td>
#       <td>0.121400</td>
#     </tr>
#     <tr>
#       <td>940</td>
#       <td>0.084600</td>
#     </tr>
#     <tr>
#       <td>950</td>
#       <td>0.065900</td>
#     </tr>
#     <tr>
#       <td>960</td>
#       <td>0.073300</td>
#     </tr>
#     <tr>
#       <td>970</td>
#       <td>0.097300</td>
#     </tr>
#     <tr>
#       <td>980</td>
#       <td>0.113100</td>
#     </tr>
#     <tr>
#       <td>990</td>
#       <td>0.030100</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.072300</td>
#     </tr>
#     <tr>
#       <td>1010</td>
#       <td>0.082800</td>
#     </tr>
#     <tr>
#       <td>1020</td>
#       <td>0.130300</td>
#     </tr>
#     <tr>
#       <td>1030</td>
#       <td>0.088800</td>
#     </tr>
#     <tr>
#       <td>1040</td>
#       <td>0.100900</td>
#     </tr>
#     <tr>
#       <td>1050</td>
#       <td>0.095600</td>
#     </tr>
#     <tr>
#       <td>1060</td>
#       <td>0.082600</td>
#     </tr>
#     <tr>
#       <td>1070</td>
#       <td>0.078600</td>
#     </tr>
#     <tr>
#       <td>1080</td>
#       <td>0.086200</td>
#     </tr>
#     <tr>
#       <td>1090</td>
#       <td>0.049800</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.090700</td>
#     </tr>
#     <tr>
#       <td>1110</td>
#       <td>0.054500</td>
#     </tr>
#     <tr>
#       <td>1120</td>
#       <td>0.059800</td>
#     </tr>
#     <tr>
#       <td>1130</td>
#       <td>0.071800</td>
#     </tr>
#     <tr>
#       <td>1140</td>
#       <td>0.099700</td>
#     </tr>
#     <tr>
#       <td>1150</td>
#       <td>0.074200</td>
#     </tr>
#     <tr>
#       <td>1160</td>
#       <td>0.056200</td>
#     </tr>
#     <tr>
#       <td>1170</td>
#       <td>0.062000</td>
#     </tr>
#     <tr>
#       <td>1180</td>
#       <td>0.0578
# 0it [00:00, ?it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 1it [00:00,  6.15it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Start testing...
# 2it [00:00,  6.52it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 3it [00:00,  6.13it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 4it [00:00,  6.71it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 5it [00:00,  6.40it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 6it [00:00,  6.30it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 7it [00:01,  6.37it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 8it [00:01,  6.35it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 9it [00:01,  6.18it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 10it [00:01,  6.20it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 11it [00:01,  6.10it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 12it [00:01,  6.17it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 13it [00:02,  6.26it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 14it [00:02,  6.15it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 15it [00:02,  6.19it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 16it [00:02,  6.28it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 17it [00:02,  6.30it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 18it [00:02,  6.57it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 19it [00:03,  6.27it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 20it [00:03,  6.07it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 21it [00:03,  5.90it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 22it [00:03,  5.99it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 23it [00:03,  6.20it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 24it [00:03,  6.34it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 25it [00:04,  6.03it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 26it [00:04,  6.17it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 27it [00:04,  6.01it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 28it [00:04,  5.96it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 29it [00:04,  6.34it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 30it [00:04,  5.53it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 31it [00:05,  5.87it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 32it [00:05,  6.03it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 33it [00:05,  6.01it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 34it [00:05,  6.01it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 35it [00:05,  5.99it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 36it [00:05,  6.11it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 37it [00:06,  6.23it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 38it [00:06,  6.40it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 39it [00:06,  6.57it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 40it [00:06,  6.23it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 41it [00:06,  6.10it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 42it [00:06,  6.17it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 43it [00:06,  6.34it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 44it [00:07,  6.13it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 45it [00:07,  6.10it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 46it [00:07,  6.04it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 47it [00:07,  5.92it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 48it [00:07,  6.09it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 49it [00:07,  6.08it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 50it [00:08,  6.07it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 51it [00:08,  5.99it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 52it [00:08,  6.02it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 53it [00:08,  5.91it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 54it [00:08,  5.93it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 55it [00:08,  6.17it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 56it [00:09,  6.18it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 57it [00:09,  6.08it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 58it [00:09,  6.06it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 59it [00:09,  6.10it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 60it [00:09,  6.09it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 61it [00:09,  6.25it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 62it [00:10,  6.17it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 63it [00:10,  6.21it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 64it [00:10,  6.01it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 65it [00:10,  6.18it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 66it [00:10,  6.21it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 67it [00:10,  6.01it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 68it [00:11,  5.94it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 69it [00:11,  6.06it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 70it [00:11,  6.11it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 71it [00:11,  6.09it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 72it [00:11,  6.08it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 73it [00:11,  6.00it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 74it [00:12,  6.06it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 75it [00:12,  5.95it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 76it [00:12,  6.00it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 77it [00:12,  6.11it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 78it [00:12,  6.09it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 79it [00:12,  6.13it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 80it [00:13,  6.00it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 81it [00:13,  6.19it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 82it [00:13,  5.95it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 83it [00:13,  6.06it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 84it [00:13,  6.30it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 85it [00:13,  6.23it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 86it [00:14,  6.29it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 87it [00:14,  6.23it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 88it [00:14,  6.07it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 89it [00:14,  6.08it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 90it [00:14,  6.27it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 91it [00:14,  5.87it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 92it [00:15,  5.93it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 93it [00:15,  5.99it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 94it [00:15,  6.08it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 95it [00:15,  6.02it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 96it [00:15,  6.13it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 97it [00:15,  6.16it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 98it [00:16,  6.06it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 99it [00:16,  6.14it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 100it [00:16,  5.95it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 101it [00:16,  5.86it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 102it [00:16,  6.32it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 103it [00:16,  6.60it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 104it [00:16,  6.51it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 105it [00:17,  6.31it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 106it [00:17,  6.42it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 107it [00:17,  6.29it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 108it [00:17,  6.25it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 109it [00:17,  6.19it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 110it [00:17,  6.20it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 111it [00:18,  6.00it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 112it [00:18,  6.05it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 113it [00:18,  6.04it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 114it [00:18,  6.20it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 115it [00:18,  6.39it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 116it [00:18,  6.28it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 117it [00:19,  6.30it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 118it [00:19,  6.54it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 119it [00:19,  6.48it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 120it [00:19,  6.44it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 121it [00:19,  6.53it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 122it [00:19,  6.84it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 123it [00:19,  6.78it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 124it [00:20,  6.71it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 125it [00:20,  6.84it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 126it [00:20,  6.72it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 127it [00:20,  7.03it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 128it [00:20,  6.88it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 129it [00:20,  6.52it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 130it [00:20,  6.63it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 131it [00:21,  6.40it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 132it [00:21,  6.31it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 133it [00:21,  6.21it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 134it [00:21,  6.21it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 135it [00:21,  5.46it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 136it [00:22,  5.53it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 137it [00:22,  5.66it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 138it [00:22,  5.72it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 139it [00:22,  5.61it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 140it [00:22,  5.90it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 141it [00:22,  5.93it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 142it [00:23,  5.96it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 143it [00:23,  6.06it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 144it [00:23,  6.15it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 145it [00:23,  6.22it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 146it [00:23,  6.34it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 147it [00:23,  6.28it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 148it [00:24,  6.30it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 149it [00:24,  6.34it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 150it [00:24,  6.30it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 151it [00:24,  5.98it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 152it [00:24,  6.55it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 153it [00:24,  6.07it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 154it [00:24,  6.16it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 155it [00:25,  6.56it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 156it [00:25,  6.46it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 157it [00:25,  6.43it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 158it [00:25,  6.10it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 159it [00:25,  6.16it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 160it [00:25,  6.24it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 161it [00:26,  6.37it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 162it [00:26,  6.21it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 163it [00:26,  6.31it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 164it [00:26,  6.08it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 165it [00:26,  6.12it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 166it [00:26,  6.09it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 167it [00:27,  6.08it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 168it [00:27,  6.08it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 169it [00:27,  6.08it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 170it [00:27,  6.07it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 171it [00:27,  6.18it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 172it [00:27,  6.04it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 173it [00:28,  5.99it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 174it [00:28,  6.01it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 175it [00:28,  6.00it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 176it [00:28,  5.93it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 177it [00:28,  6.07it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 178it [00:28,  6.18it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 179it [00:29,  6.22it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 180it [00:29,  6.25it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 181it [00:29,  6.21it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 182it [00:29,  6.23it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 183it [00:29,  6.33it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 184it [00:29,  6.22it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 185it [00:30,  6.09it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 186it [00:30,  6.09it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 187it [00:30,  6.19it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 188it [00:30,  6.19it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 189it [00:30,  6.16it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 190it [00:30,  6.23it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 191it [00:30,  6.14it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 192it [00:31,  5.99it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 193it [00:31,  6.10it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 194it [00:31,  6.01it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 195it [00:31,  6.09it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 196it [00:31,  5.98it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 197it [00:31,  5.92it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 198it [00:32,  6.25it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 199it [00:32,  6.20it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 200it [00:32,  6.15it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 201it [00:32,  6.26it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 202it [00:32,  6.19it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 203it [00:32,  6.11it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 204it [00:33,  6.13it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 205it [00:33,  6.16it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 206it [00:33,  6.04it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 207it [00:33,  6.30it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 208it [00:33,  6.18it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 209it [00:33,  6.23it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 210it [00:34,  6.28it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 211it [00:34,  6.17it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 212it [00:34,  6.05it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 213it [00:34,  6.22it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 214it [00:34,  6.09it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 215it [00:34,  6.14it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 216it [00:35,  6.37it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 217it [00:35,  6.67it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 218it [00:35,  6.45it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 219it [00:35,  6.55it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 220it [00:35,  6.56it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 221it [00:35,  6.60it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 222it [00:35,  6.68it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 223it [00:36,  6.55it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 224it [00:36,  6.38it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 225it [00:36,  6.28it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 226it [00:36,  6.14it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 227it [00:36,  5.94it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 228it [00:36,  5.88it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 229it [00:37,  5.82it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 230it [00:37,  5.98it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 231it [00:37,  6.09it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 232it [00:37,  6.17it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 233it [00:37,  6.21it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 234it [00:37,  6.24it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 235it [00:38,  6.29it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 236it [00:38,  6.35it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 237it [00:38,  6.44it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 238it [00:38,  6.40it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 239it [00:38,  6.45it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 240it [00:38,  6.41it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 241it [00:38,  6.40it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 242it [00:39,  6.22it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 243it [00:39,  6.25it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 244it [00:39,  6.30it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 245it [00:39,  6.37it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 246it [00:39,  6.32it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 247it [00:39,  6.26it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 248it [00:40,  6.22it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 249it [00:40,  6.23it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 250it [00:40,  6.18it/s]
# 0.9226059438635114

# %%
import torch
torch.save(model,'GPT-2-IRCTC.pt')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e370079f27f9> in <module>
#       1 import torch
# ----> 2 torch.save(model,'GPT-2-IRCTC.pt')
#
# NameError: name 'model' is not defined

# %%
model
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-1f8a688cae5d> in <module>
# ----> 1 model
#
# NameError: name 'model' is not defined
